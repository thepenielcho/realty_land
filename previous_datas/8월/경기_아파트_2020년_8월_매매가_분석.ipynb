# %%
import pandas as pd
import numpy as np

# %%
ap_gg=pd.read_csv('/content/drive/My Drive/주택가격/8월/경기아파트(매매)__실거래가_20200902164216.csv',
                  encoding='EUC-KR')
ap_gg.head()
# Out:
#                시군구      번지   본번  부번  ... 거래금액(만원)   층  건축년도       도로명
# 0  경기도 가평군 가평읍 달전리   285-1  285   1  ...     8300  11  1993    달전로 64
# 1  경기도 가평군 가평읍 대곡리  230-18  230  18  ...    25000   7  2019  굴다리길 7-1
# 2  경기도 가평군 가평읍 읍내리   771-1  771   1  ...    21500  10  2007   가화로 223
# 3   경기도 가평군 조종면 현리  258-20  258  20  ...    15500   3  1998     38-20
# 4  경기도 가평군 청평면 청평리     306  306   0  ...    19150   8  2008  골안길 7-28
#
# [5 rows x 12 columns]

# %%
ap_gg['구']=[eachAddress.split()[1] for eachAddress in ap_gg['시군구']]
ap_gg.head()
# Out:
#                시군구      번지   본번  부번  ...   층  건축년도       도로명    구
# 0  경기도 가평군 가평읍 달전리   285-1  285   1  ...  11  1993    달전로 64  가평군
# 1  경기도 가평군 가평읍 대곡리  230-18  230  18  ...   7  2019  굴다리길 7-1  가평군
# 2  경기도 가평군 가평읍 읍내리   771-1  771   1  ...  10  2007   가화로 223  가평군
# 3   경기도 가평군 조종면 현리  258-20  258  20  ...   3  1998     38-20  가평군
# 4  경기도 가평군 청평면 청평리     306  306   0  ...   8  2008  골안길 7-28  가평군
#
# [5 rows x 13 columns]

# %%
ap_gg['동']=[eachAddress.split()[2] for eachAddress in ap_gg['시군구']]
ap_gg.head()
# Out:
#                시군구      번지   본번  부번       단지명  ...   층  건축년도       도로명    구    동
# 0  경기도 가평군 가평읍 달전리   285-1  285   1        신초  ...  11  1993    달전로 64  가평군  가평읍
# 1  경기도 가평군 가평읍 대곡리  230-18  230  18  삼성웰타운아파트  ...   7  2019  굴다리길 7-1  가평군  가평읍
# 2  경기도 가평군 가평읍 읍내리   771-1  771   1    에이원파란채  ...  10  2007   가화로 223  가평군  가평읍
# 3   경기도 가평군 조종면 현리  258-20  258  20        청수  ...   3  1998     38-20  가평군  조종면
# 4  경기도 가평군 청평면 청평리     306  306   0    경남아너스빌  ...   8  2008  골안길 7-28  가평군  청평면
#
# [5 rows x 14 columns]

# %%
ap_gg.sort_values(by='거래금액(만원)', ascending=False).head(10)
# Out:
#                 시군구    번지    본번  부번  ...  건축년도           도로명      구    동
# 3048  경기도 성남분당구 정자동     6     6   0  ...  2004      정자일로 248  성남분당구  정자동
# 3047  경기도 성남분당구 정자동     6     6   0  ...  2004      정자일로 248  성남분당구  정자동
# 3075  경기도 성남분당구 판교동   629   629   0  ...  2009        판교로 20  성남분당구  판교동
# 2968  경기도 성남분당구 삼평동   738   738   0  ...  2009      동판교로 155  성남분당구  삼평동
# 2970  경기도 성남분당구 삼평동   740   740   0  ...  2012  동판교로177번길 25  성남분당구  삼평동
# 2969  경기도 성남분당구 삼평동   742   742   0  ...  2009      동판교로 153  성남분당구  삼평동
# 3046  경기도 성남분당구 정자동  28-1    28   1  ...  2003      성남대로 449  성남분당구  정자동
# 3635   경기도 수원영통구 하동  1021  1021   0  ...  2018      센트럴파크로 6  수원영통구   하동
# 2987  경기도 성남분당구 수내동    36    36   0  ...  1992       내정로 185  성남분당구  수내동
# 2971  경기도 성남분당구 서현동    87    87   0  ...  1991      중앙공원로 53  성남분당구  서현동
#
# [10 rows x 14 columns]

# %%
ap_gg.sort_values(by='거래금액(만원)', ascending=True).head(10)
# Out:
#                   시군구      번지    본번  부번  ...  건축년도            도로명    구    동
# 4367  경기도 안성시 공도읍 마정리    45-6    45   6  ...  1997       가족공원길 86  안성시  공도읍
# 4368  경기도 안성시 공도읍 마정리    45-6    45   6  ...  1997       가족공원길 86  안성시  공도읍
# 4366  경기도 안성시 공도읍 마정리    45-6    45   6  ...  1997       가족공원길 86  안성시  공도읍
# 7873      경기도 화성시 반송동   107-4   107   4  ...  2007  동탄문화센터로 71-17  화성시  반송동
# 7608  경기도 포천시 신북면 가채리    30-2    30   2  ...  2003    호국로 1886-76  포천시  신북면
# 7612  경기도 포천시 신북면 기지리   101-6   101   6  ...  1995    호국로 2135-11  포천시  신북면
# 7543  경기도 평택시 포승읍 도곡리  1118-7  1118   7  ...  2013        여술1길 83  평택시  포승읍
# 6537  경기도 이천시 부발읍 무촌리   221-2   221   2  ...  1989      무촌로 147-1  이천시  부발읍
# 7496  경기도 평택시 진위면 견산리     374   374   0  ...  1992       견산1길 3-5  평택시  진위면
# 3841      경기도 시흥시 거모동   612-1   612   1  ...  1999    군자로335번길 11  시흥시  거모동
#
# [10 rows x 14 columns]

# %%
# !pip install folium

# %%
# !pip install googlemaps
# Out:
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.4.2-cp36-none-any.whl size=37858 sha256=59804b9da00616968dd0ad6a14dc30259dedad99051087de51bd57c90273c80e
#   Stored in directory: /root/.cache/pip/wheels/f4/21/41/0c84572e21d52bb322f6c299f38ac7cd8ad6d4d6ce23dc3631
# Successfully built googlemaps
# ...

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
gg_ap_50=ap_gg.sort_values(by='거래금액(만원)',ascending=False).head(50)
gg_ap_50.head()
# Out:
#                 시군구   번지   본번  부번  ...  건축년도           도로명      구    동
# 3048  경기도 성남분당구 정자동    6    6   0  ...  2004      정자일로 248  성남분당구  정자동
# 3047  경기도 성남분당구 정자동    6    6   0  ...  2004      정자일로 248  성남분당구  정자동
# 3075  경기도 성남분당구 판교동  629  629   0  ...  2009        판교로 20  성남분당구  판교동
# 2968  경기도 성남분당구 삼평동  738  738   0  ...  2009      동판교로 155  성남분당구  삼평동
# 2970  경기도 성남분당구 삼평동  740  740   0  ...  2012  동판교로177번길 25  성남분당구  삼평동
#
# [5 rows x 14 columns]

# %%
gg_ap_b50=ap_gg.sort_values(by='거래금액(만원)',ascending=True).head(50)
gg_ap_b50.head()
# Out:
#                   시군구     번지   본번  부번  ...  건축년도            도로명    구    동
# 4367  경기도 안성시 공도읍 마정리   45-6   45   6  ...  1997       가족공원길 86  안성시  공도읍
# 4368  경기도 안성시 공도읍 마정리   45-6   45   6  ...  1997       가족공원길 86  안성시  공도읍
# 4366  경기도 안성시 공도읍 마정리   45-6   45   6  ...  1997       가족공원길 86  안성시  공도읍
# 7873      경기도 화성시 반송동  107-4  107   4  ...  2007  동탄문화센터로 71-17  화성시  반송동
# 7608  경기도 포천시 신북면 가채리   30-2   30   2  ...  2003    호국로 1886-76  포천시  신북면
#
# [5 rows x 14 columns]

# %%
gg_ap_50['주소']=gg_ap_50['구']+' '+gg_ap_50['동']+' '+gg_ap_50['도로명']
gg_ap_50.head()
# Out:
#                 시군구   번지   본번  ...      구    동                      주소
# 3048  경기도 성남분당구 정자동    6    6  ...  성남분당구  정자동      성남분당구 정자동 정자일로 248
# 3047  경기도 성남분당구 정자동    6    6  ...  성남분당구  정자동      성남분당구 정자동 정자일로 248
# 3075  경기도 성남분당구 판교동  629  629  ...  성남분당구  판교동        성남분당구 판교동 판교로 20
# 2968  경기도 성남분당구 삼평동  738  738  ...  성남분당구  삼평동      성남분당구 삼평동 동판교로 155
# 2970  경기도 성남분당구 삼평동  740  740  ...  성남분당구  삼평동  성남분당구 삼평동 동판교로177번길 25
#
# [5 rows x 15 columns]

# %%
gg_ap_b50['주소']=gg_ap_b50['구']+' '+gg_ap_b50['동']+' '+gg_ap_b50['도로명']
gg_ap_b50.head()
# Out:
#                   시군구     번지   본번  ...    구    동                     주소
# 4367  경기도 안성시 공도읍 마정리   45-6   45  ...  안성시  공도읍       안성시 공도읍 가족공원길 86
# 4368  경기도 안성시 공도읍 마정리   45-6   45  ...  안성시  공도읍       안성시 공도읍 가족공원길 86
# 4366  경기도 안성시 공도읍 마정리   45-6   45  ...  안성시  공도읍       안성시 공도읍 가족공원길 86
# 7873      경기도 화성시 반송동  107-4  107  ...  화성시  반송동  화성시 반송동 동탄문화센터로 71-17
# 7608  경기도 포천시 신북면 가채리   30-2   30  ...  포천시  신북면    포천시 신북면 호국로 1886-76
#
# [5 rows x 15 columns]
