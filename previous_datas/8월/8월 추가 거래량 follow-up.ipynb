# %%
import numpy as np
import pandas as pd

# %%
ap_price=pd.read_csv('/content/drive/My Drive/주택가격/8월/아파트(매매)__실거래가_20200919171557.csv',
                     encoding='EUc-KR')
ap_price
# Out:
#                 시군구      번지   본번  부번  ... 거래금액(만원)   층  건축년도         도로명
# 0     서울특별시 강남구 개포동    12-2   12   2  ...   252000   8  2004  개포로109길 69
# 1     서울특별시 강남구 개포동     187  187   0  ...   215000   2  1983    삼성로4길 17
# 2     서울특별시 강남구 개포동     187  187   0  ...   190000   3  1983    삼성로4길 17
# 3     서울특별시 강남구 개포동     187  187   0  ...   205000  14  1983    삼성로4길 17
# 4     서울특별시 강남구 개포동     187  187   0  ...   189000   9  1983    삼성로4길 17
# ...             ...     ...  ...  ..  ...      ...  ..   ...         ...
# 4584  서울특별시 중랑구 중화동     450  450   0  ...    60800  26  1997     동일로 752
# 4585  서울특별시 중랑구 중화동     450  450   0  ...    61600  18  1997     동일로 752
# 4586  서울특별시 중랑구 중화동     450  450   0  ...    74000  10  1997     동일로 752
# 4587  서울특별시 중랑구 중화동     450  450   0  ...    60000  18  1998     동일로 752
# 4588  서울특별시 중랑구 중화동  274-77  274  77  ...    26000   2  2003  동일로144길 74
#
# [4589 rows x 12 columns]

# %%
pv_ap_price=pd.read_csv('/content/drive/My Drive/주택가격/8월/서울아파트(매매)__실거래가_20200902164101.csv',
                     encoding='EUC-KR')
pv_ap_price
# Out:
#                 시군구      번지   본번  부번  ... 거래금액(만원)   층  건축년도         도로명
# 0     서울특별시 강남구 개포동    12-2   12   2  ...   252000   8  2004  개포로109길 69
# 1     서울특별시 강남구 개포동     187  187   0  ...   215000   2  1983    삼성로4길 17
# 2     서울특별시 강남구 개포동     187  187   0  ...   190000   3  1983    삼성로4길 17
# 3     서울특별시 강남구 개포동     187  187   0  ...   215000   5  1983    삼성로4길 17
# 4     서울특별시 강남구 개포동     187  187   0  ...   210000  13  1983    삼성로4길 17
# ...             ...     ...  ...  ..  ...      ...  ..   ...         ...
# 2362  서울특별시 중랑구 중화동     450  450   0  ...    60500   4  1997     동일로 752
# 2363  서울특별시 중랑구 중화동     450  450   0  ...    61500   8  1997     동일로 752
# 2364  서울특별시 중랑구 중화동     450  450   0  ...    72800  15  1997     동일로 752
# 2365  서울특별시 중랑구 중화동     450  450   0  ...    70300  15  1997     동일로 752
# 2366  서울특별시 중랑구 중화동  274-77  274  77  ...    26000   2  2003  동일로144길 74
#
# [2367 rows x 12 columns]
