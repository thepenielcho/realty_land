# %%
import pandas as pd
import numpy as np

# %%
ap_price=pd.read_csv('/content/drive/My Drive/주택가격/9월/아파트(매매)__실거래가_20201004224707.csv',
                     encoding='EUC-KR')
ap_price
# Out:
#                 시군구      번지   본번  부번  ... 거래금액(만원)   층  건축년도         도로명
# 0     서울특별시 강남구 개포동     187  187   0  ...   230000  14  1983    삼성로4길 17
# 1     서울특별시 강남구 개포동     187  187   0  ...   184000   8  1983    삼성로4길 17
# 2     서울특별시 강남구 개포동     187  187   0  ...   184000   7  1983    삼성로4길 17
# 3     서울특별시 강남구 개포동     187  187   0  ...   230000  14  1983    삼성로4길 17
# 4     서울특별시 강남구 개포동     185  185   0  ...   185000   6  1983     개포로 516
# ...             ...     ...  ...  ..  ...      ...  ..   ...         ...
# 1888  서울특별시 중랑구 신내동     657  657   0  ...    45700   5  1996     신내로 127
# 1889  서울특별시 중랑구 신내동     656  656   0  ...    60000   4  1995     신내로 155
# 1890  서울특별시 중랑구 중화동   307-6  307   6  ...    43900   2  2004     동일로 829
# 1891  서울특별시 중랑구 중화동  286-22  286  22  ...    64500   2  2004  동일로136길 10
# 1892  서울특별시 중랑구 중화동     450  450   0  ...    61000  12  1997     동일로 752
#
# [1893 rows x 12 columns]

# %%
ap_price.sort_values(by='거래금액(만원)', ascending=False).head()
# Out:
#                  시군구       번지    본번  부번  ... 거래금액(만원)   층  건축년도        도로명
# 1715   서울특별시 용산구 한남동      810   810   0  ...   730000   3  2011   독서당로 111
# 1272   서울특별시 서초구 서초동  1496-24  1496  24  ...   520000   8  2002  명달로 97-14
# 1233   서울특별시 서초구 반포동    20-43    20  43  ...   485000  23  2009   신반포로 270
# 42    서울특별시 강남구 압구정동      433   433   0  ...   445000  11  1983   압구정로 151
# 1230   서울특별시 서초구 반포동     18-1    18   1  ...   423000   4  2009   반포대로 275
#
# [5 rows x 12 columns]

# %%
ap_price.sort_values(by='거래금액(만원)', ascending=True).head()
# Out:
#                 시군구      번지    본번  부번  ... 거래금액(만원)  층  건축년도             도로명
# 532   서울특별시 구로구 구로동  807-21   807  21  ...     7000  2  1998       구로동로 82-9
# 526   서울특별시 구로구 구로동  771-30   771  30  ...     8500  5  1996    구로동로18길 61-5
# 135   서울특별시 강동구 성내동   244-5   244   5  ...     8500  8  2014  천호대로176길 10-10
# 530   서울특별시 구로구 구로동  798-55   798  55  ...     8850  3  1998   디지털로27길 120-3
# 1863  서울특별시 중랑구 면목동    1535  1535   0  ...     9000  3  2013      동일로109가길 5
#
# [5 rows x 12 columns]

# %%
ap_price['면적당금액']=ap_price['거래금액(만원)']/ap_price['전용면적(㎡)']
ap_price.sort_values(by='면적당금액', ascending=False).head()
# Out:
#                 시군구      번지   본번  부번  ...   층  건축년도          도로명        면적당금액
# 1236  서울특별시 서초구 반포동    2-12    2  12  ...  11  2016   신반포로15길 19  4226.015303
# 1229  서울특별시 서초구 반포동    18-1   18   1  ...   6  2009     반포대로 275  3835.890594
# 1714  서울특별시 용산구 한남동     810  810   0  ...   9  2011     독서당로 111  3769.728244
# 1237  서울특별시 서초구 반포동    2-12    2  12  ...   3  2016   신반포로15길 19  3530.657879
# 74    서울특별시 강남구 청담동  134-38  134  38  ...  10  2011  영동대로138길 12  3528.723812
#
# [5 rows x 13 columns]

# %%
ap_price.describe()
# Out:
#                 본번           부번  ...         건축년도        면적당금액
# count  1893.000000  1893.000000  ...  1893.000000  1893.000000
# mean    562.474908     7.623877  ...  2000.872689  1142.675557
# std     482.801499    70.088181  ...     9.947067   524.396270
# min       0.000000     0.000000  ...  1967.000000   243.331774
# 25%     199.000000     0.000000  ...  1994.000000   809.091980
# 50%     481.000000     0.000000  ...  2001.000000  1035.526847
# 75%     785.000000     1.000000  ...  2008.000000  1354.581673
# max    4955.000000  2745.000000  ...  2020.000000  4226.015303
#
# [8 rows x 9 columns]

# %%
ap_price['구']=[eachAddress.split()[1] for eachAddress in ap_price['시군구']]
ap_price.head()
# Out:
#              시군구   번지   본번  부번       단지명  ...   층  건축년도       도로명        면적당금액    구
# 0  서울특별시 강남구 개포동  187  187   0  개포주공 5단지  ...  14  1983  삼성로4길 17  2765.420224  강남구
# 1  서울특별시 강남구 개포동  187  187   0  개포주공 5단지  ...   8  1983  삼성로4길 17  3408.669878  강남구
# 2  서울특별시 강남구 개포동  187  187   0  개포주공 5단지  ...   7  1983  삼성로4길 17  3408.669878  강남구
# 3  서울특별시 강남구 개포동  187  187   0  개포주공 5단지  ...  14  1983  삼성로4길 17  2765.420224  강남구
# 4  서울특별시 강남구 개포동  185  185   0  개포주공 6단지  ...   6  1983   개포로 516  3076.667221  강남구
#
# [5 rows x 14 columns]

# %%
ap_price['구'].unique()
# Out:
# array(['강남구', '강동구', '강북구', '강서구', '관악구', '광진구', '구로구', '금천구', '노원구',
#        '도봉구', '동대문구', '동작구', '마포구', '서대문구', '서초구', '성동구', '성북구', '송파구',
#        '양천구', '영등포구', '용산구', '은평구', '종로구', '중구', '중랑구'], dtype=object)

# %%
len(ap_price['구'].unique())
# Out:
# 25

# %%
ap_price['동']=[eachAddress.split()[2] for eachAddress in ap_price['시군구']]
ap_price.head()
# Out:
#              시군구   번지   본번  부번       단지명  ...  건축년도       도로명        면적당금액    구    동
# 0  서울특별시 강남구 개포동  187  187   0  개포주공 5단지  ...  1983  삼성로4길 17  2765.420224  강남구  개포동
# 1  서울특별시 강남구 개포동  187  187   0  개포주공 5단지  ...  1983  삼성로4길 17  3408.669878  강남구  개포동
# 2  서울특별시 강남구 개포동  187  187   0  개포주공 5단지  ...  1983  삼성로4길 17  3408.669878  강남구  개포동
# 3  서울특별시 강남구 개포동  187  187   0  개포주공 5단지  ...  1983  삼성로4길 17  2765.420224  강남구  개포동
# 4  서울특별시 강남구 개포동  185  185   0  개포주공 6단지  ...  1983   개포로 516  3076.667221  강남구  개포동
#
# [5 rows x 15 columns]

# %%
len(ap_price['동'].unique())
# Out:
# 216

# %%
ap_sum=ap_price

# %%
ap_sum=ap_sum.drop(['시군구','번지','본번','부번','전용면적(㎡)','계약년월','계약일'],1)
ap_sum.head()
# Out:
#         단지명  거래금액(만원)   층  건축년도       도로명        면적당금액    구    동
# 0  개포주공 5단지    230000  14  1983  삼성로4길 17  2765.420224  강남구  개포동
# 1  개포주공 5단지    184000   8  1983  삼성로4길 17  3408.669878  강남구  개포동
# 2  개포주공 5단지    184000   7  1983  삼성로4길 17  3408.669878  강남구  개포동
# 3  개포주공 5단지    230000  14  1983  삼성로4길 17  2765.420224  강남구  개포동
# 4  개포주공 6단지    185000   6  1983   개포로 516  3076.667221  강남구  개포동

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import platform

path = "c:/Windows/Fonts/malgun.ttf"
from matplotlib import font_manager, rc
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')
# Out:
# Unknown system... sorry~~~~

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='구', y='면적당금액', data=ap_sum, palette='Set3')
plt.show()

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='구', y='거래금액(만원)', data=ap_sum, palette='Set3')
plt.show()

# %%
# !pip install folium

# %%
# !pip install googlemaps
# Out:
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.4.2-cp36-none-any.whl size=37858 sha256=ef19cfae6b0d36e7b7bc8a7236a690083c8817d3d7fbf84e0560773900f0cf89
#   Stored in directory: /root/.cache/pip/wheels/f4/21/41/0c84572e21d52bb322f6c299f38ac7cd8ad6d4d6ce23dc3631
# Successfully built googlemaps
# ...

# %%
import json
import folium
import googlemaps
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
ap_sum.sort_values(by='면적당금액',ascending=False).head(10)
# Out:
#              단지명  거래금액(만원)   층  건축년도          도로명        면적당금액    구     동
# 1236     아크로리버파크    359000  11  2016   신반포로15길 19  4226.015303  서초구   반포동
# 1229     래미안퍼스티지    230000   6  2009     반포대로 275  3835.890594  서초구   반포동
# 1714        한남더힐    225000   9  2011     독서당로 111  3769.728244  용산구   한남동
# 1237     아크로리버파크    300000   3  2016   신반포로15길 19  3530.657879  서초구   반포동
# 74          청담자이    175000  10  2011  영동대로138길 12  3528.723812  강남구   청담동
# 1232    반포 주공1단지    375000   5  1973      신반포로 45  3489.345864  서초구   반포동
# 44    한양1차(영동한양)    170500   1  1977     압구정로 321  3411.364546  강남구  압구정동
# 1       개포주공 5단지    184000   8  1983     삼성로4길 17  3408.669878  강남구   개포동
# 2       개포주공 5단지    184000   7  1983     삼성로4길 17  3408.669878  강남구   개포동
# 1231    반포 주공1단지    352000   3  1973       신반포로 9  3355.896654  서초구   반포동

# %%
ap_sum.sort_values(by='거래금액(만원)',ascending=False).head(10)
# Out:
#            단지명  거래금액(만원)   층  건축년도        도로명        면적당금액    구     동
# 1715      한남더힐    730000   3  2011   독서당로 111  3038.754527  용산구   한남동
# 1272   트라움하우스3    520000   8  2002  명달로 97-14  1898.780399  서초구   서초동
# 1233      반포자이    485000  23  2009   신반포로 270  1982.602155  서초구   반포동
# 42      신현대11차    445000  11  1983   압구정로 151  2595.811702  강남구  압구정동
# 1230   래미안퍼스티지    423000   4  2009   반포대로 275  2508.152980  서초구   반포동
# 43       신현대9차    420000   9  1982   압구정로 151  2758.077226  강남구  압구정동
# 1234      반포자이    380000   3  2009   신반포로 270  2296.821924  서초구   반포동
# 29      타워팰리스1    376000  45  2002  언주로30길 56  2152.630675  강남구   도곡동
# 17      동부센트레빌    375000   7  2005    선릉로 206  2571.487348  강남구   대치동
# 1232  반포 주공1단지    375000   5  1973    신반포로 45  3489.345864  서초구   반포동

# %%
ap_sum.describe()
# Out:
#             거래금액(만원)            층         건축년도        면적당금액
# count    1893.000000  1893.000000  1893.000000  1893.000000
# mean    85982.961965     8.966719  2000.872689  1142.675557
# std     57992.286826     5.858123     9.947067   524.396270
# min      7000.000000    -1.000000  1967.000000   243.331774
# 25%     51000.000000     4.000000  1994.000000   809.091980
# 50%     74400.000000     8.000000  2001.000000  1035.526847
# 75%    102000.000000    12.000000  2008.000000  1354.581673
# max    730000.000000    45.000000  2020.000000  4226.015303

# %%
ap_sum.건축년도.count()
# Out:
# 1893

# %%
ap_sum.건축년도
