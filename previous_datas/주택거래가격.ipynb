# %%
import pandas as pd
import numpy as np

# %%
ap_price = pd.read_csv('/content/drive/My Drive/주택가격/아파트(매매)__실거래가_20200829221104.csv', encoding='EUC-KR', lineterminator='\r') #sep='\t',

# %%
ap_price
